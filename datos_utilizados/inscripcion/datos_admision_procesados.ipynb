# %% [markdown]
# ## Archivo de admision 2024

# %%
import pandas as pd

# %%
df = pd.read_csv("ArchivoC_ADM2024.csv", sep=";", low_memory=False)

# %%
df = df.drop(columns=["MATE1_REG_ANTERIOR", "MATE2_REG_ANTERIOR", "HCSOC_REG_ANTERIOR", "CIEN_REG_ANTERIOR", "MODULO_REG_ANTERIOR", "CLEC_INV_ANTERIOR", "MATE_INV_ANTERIOR", "HCSOC_INV_ANTERIOR", "CIEN_INV_ANTERIOR", "CLEC_REG_ANTERIOR", "MODULO_INV_ANTERIOR"])

# %%
df
# Out:
#                   ID_aux      RBD  COD_ENS  GRUPO_DEPENDENCIA  \
# 0       id_0000900470001  10399.0    410.0                3.0
# 1       id_0000900470008   8553.0    363.0                3.0
# 2       id_0001900470101  25502.0    363.0                2.0
# 3       id_0001900470177      NaN      NaN                NaN
# 4       id_0001900670170  40320.0    310.0                2.0
# ...                  ...      ...      ...                ...
# 306492  id_9999599979938    191.0    510.0                3.0
# 306493  id_9999599979949   5652.0    310.0                2.0
# 306494  id_9999599979957   6348.0    610.0                4.0
# 306495  id_9999599979962   6644.0    310.0                2.0
# 306496  id_9999599979982  20053.0    610.0                4.0
#
#        RAMA_EDUCACIONAL  SITUACION_EGRESO  CODIGO_REGION  CODIGO_COMUNA  \
# 0                    T1                 5           13.0        13301.0
# 1                    H2                 5           13.0        13127.0
# ...
