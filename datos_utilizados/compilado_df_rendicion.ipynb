# %% [markdown]
# ## Rendicion

# %%
import pandas as pd

# %% [markdown]
# ## 2023

# %%
df = pd.read_csv("rendicion/2023/ArchivoC_Adm2023.csv", sep=";", low_memory=False)

# %%
df = df.drop(columns=["MATE1_REG_ANTERIOR", "HCSOC_REG_ANTERIOR", "CIEN_REG_ANTERIOR", "MODULO_REG_ANTERIOR", "CLEC_REG_ANTERIOR"])

# %%
df
# Out:
#                   ID_aux      RBD  COD_ENS  GRUPO_DEPENDENCIA  \
# 0       id_0000900170003  10584.0    363.0                3.0
# 1       id_0000900470024  10250.0    363.0                3.0
# 2       id_0000900670068  12667.0    310.0                2.0
# 3       id_0001900070103   7006.0    310.0                2.0
# 4       id_0001900070149   6752.0    610.0                3.0
# ...                  ...      ...      ...                ...
# 293860  id_9999599979968  31002.0    310.0                2.0
# 293861   id_999990948930  25783.0    410.0                2.0
# 293862   id_999994942103    705.0    510.0                3.0
# 293863   id_999997943080      NaN      NaN                NaN
# 293864  id_9999999879976   9877.0    363.0                3.0
#
#        RAMA_EDUCACIONAL  SITUACION_EGRESO  CODIGO_REGION  CODIGO_COMUNA  \
# 0                    H2                 5           13.0        13401.0
# 1                    H2                 1           13.0        13107.0
# ...

# %% [markdown]
# ## 2022

# %%
df = pd.read_csv("rendicion/2022/ArchivoC_Adm2022.csv", sep=";", low_memory=False)

# %%
df = df.drop(columns=["PROMEDIO_CM_ANTERIOR", "PERCENTIL_CM_ANTERIOR", "MODULO_ANTERIOR", "CIEN_ANTERIOR", "HCSO_ANTERIOR", "MATE_ANTERIOR", "CLEC_ANTERIOR"])

# %%
df
# Out:
#                   ID_aux      RBD  COD_ENS  GRUPO_DEPENDENCIA  \
# 0       id_0000900070036   7006.0    310.0                2.0
# 1       id_0000900370001  20443.0    363.0                2.0
# 2       id_0000900370094  20443.0    363.0                2.0
# 3       id_0000900370098  14210.0    310.0                2.0
# 4       id_0000900470074  25818.0    363.0                2.0
# ...                  ...      ...      ...                ...
# 254186  id_9999599979969   6253.0    310.0                2.0
# 254187  id_9999599979970   6163.0    410.0                3.0
# 254188  id_9999599979971   6163.0    610.0                3.0
# 254189  id_9999599979986   6398.0    310.0                4.0
# 254190  id_9999599979998   9332.0    310.0                2.0
#
#        RAMA_EDUCACIONAL  SITUACION_EGRESO  CODIGO_REGION  CODIGO_COMUNA  \
# 0                    H1                 5           14.0        14202.0
# 1                    H2                 1            5.0         5502.0
# ...

# %% [markdown]
# ## 2020

# %%
df = pd.read_csv("rendicion/2020/ArchivoC_Adm2020.csv", sep=";", low_memory=False)

# %%
df = df.drop(columns=["LENG_ANTERIOR", "MATE_ANTERIOR", "HCSO_ANTERIOR", "CIEN_ANTERIOR", "MODULO_ANTERIOR", "PROMEDIO_LM_ANTERIOR", "PERCENTIL_LM_ANTERIOR"])

# %%
df
# Out:
#                   ID_aux      RBD  COD_ENS  GRUPO_DEPENDENCIA  \
# 0        id_.9+85.97e+83   5219.0    510.0                3.0
# 1       id_0000900070019  22388.0    363.0                2.0
# 2       id_0000900070043  22374.0    363.0                2.0
# 3       id_0000900270075  12696.0    563.0                2.0
# 4       id_0000900470040  24900.0    363.0                3.0
# ...                  ...      ...      ...                ...
# 292086  id_9999599479904  24482.0    510.0                2.0
# 292087  id_9999599479967   8618.0    310.0                2.0
# 292088  id_9999599479973  20316.0    363.0                2.0
# 292089  id_9999599479977  14373.0    310.0                2.0
# 292090  id_9999599779976    574.0    510.0                2.0
#
#        RAMA_EDUCACIONAL  SITUACION_EGRESO  CODIGO_REGION  CODIGO_COMUNA  \
# 0                    T2                 1            9.0         9201.0
# 1                    H2                 5           14.0        14101.0
# ...

# %% [markdown]
# ## 2017

# %%
df = pd.read_csv("rendicion/2020/ArchivoC_Adm2020.csv", sep=";", low_memory=False)

# %%
df = df.drop(columns=["LENG_ANTERIOR", "MATE_ANTERIOR", "HCSO_ANTERIOR", "CIEN_ANTERIOR", "MODULO_ANTERIOR", "PROMEDIO_LM_ANTERIOR", "PERCENTIL_LM_ANTERIOR"])

# %%
df
# Out:
#                   ID_aux      RBD  COD_ENS  GRUPO_DEPENDENCIA  \
# 0        id_.9+85.97e+83   5219.0    510.0                3.0
# 1       id_0000900070019  22388.0    363.0                2.0
# 2       id_0000900070043  22374.0    363.0                2.0
# 3       id_0000900270075  12696.0    563.0                2.0
# 4       id_0000900470040  24900.0    363.0                3.0
# ...                  ...      ...      ...                ...
# 292086  id_9999599479904  24482.0    510.0                2.0
# 292087  id_9999599479967   8618.0    310.0                2.0
# 292088  id_9999599479973  20316.0    363.0                2.0
# 292089  id_9999599479977  14373.0    310.0                2.0
# 292090  id_9999599779976    574.0    510.0                2.0
#
#        RAMA_EDUCACIONAL  SITUACION_EGRESO  CODIGO_REGION  CODIGO_COMUNA  \
# 0                    T2                 1            9.0         9201.0
# 1                    H2                 5           14.0        14101.0
# ...
