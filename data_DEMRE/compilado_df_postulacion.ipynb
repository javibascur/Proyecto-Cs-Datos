# %% [markdown]
# ## Postulaciones

# %%
import pandas as pd

# %% [markdown]
# ## 2023

# %%
df = pd.read_csv("datos_utilizados/postulacion/2023/ArchivoD_Adm2023.csv", sep=";", low_memory=False)

# %%
df
# Out:
#                   ID_aux SITUACION_POSTULANTE  COD_CARRERA_PREF_01  \
# 0       id_0001900070103                    P                55105
# 1       id_0001900170136                    P                11083
# 2       id_0001900670175                    P                23077
# 3       id_0001900870116                    P                34086
# 4       id_0002900370264                    P                55038
# ...                  ...                  ...                  ...
# 186059  id_9999599979931                    P                50927
# 186060  id_9999599979949                    P                37020
# 186061  id_9999599979953                    P                50525
# 186062  id_9999599979968                    P                17037
# 186063   id_999997943080                    P                41031
#
#         ESTADO_PREF_01 PTJE_PREF_01  COD_CARRERA_PREF_02  ESTADO_PREF_02  \
# 0                   25        543,9                    0               0
# ...

# %% [markdown]
# ## 2022

# %%
df = pd.read_csv("datos_utilizados/postulacion/2022/ArchivoD_Adm2022.csv", sep=";", low_memory=False)

# %%
df
# Out:
#                   ID_aux SITUACION_POSTULANTE  COD_CARRERA_PREF_01  \
# 0       id_0000900370098                    P                55044
# 1       id_0001900170136                    P                49004
# 2       id_0001900170151                    P                16108
# 3       id_0001900170189                    C                55029
# 4       id_0001900870175                    P                50113
# ...                  ...                  ...                  ...
# 147723  id_9999599979966                    P                30068
# 147724  id_9999599979967                    P                17005
# 147725  id_9999599979968                    P                37092
# 147726  id_9999599979969                    P                17000
# 147727  id_9999599979971                    P                30020
#
#         ESTADO_PREF_01 PTJE_PREF_01  POND_ACAD_PREF_01  COD_CARRERA_PREF_02  \
# 0                   25        551,1                  1                55065
# ...

# %% [markdown]
# ## 2020

# %%
df = pd.read_csv("datos_utilizados/postulacion/2020/ArchivoD_Adm2020.csv", sep=";", low_memory=False)

# %%
df
# Out:
#                   ID_aux SITUACION_POSTULANTE  COD_CARRERA_PREF_01  \
# 0       id_0000900570066                    C                12060
# 1       id_0000900570071                    P                20022
# 2       id_0000900970028                    P                32016
# 3       id_0000900970096                    P                48008
# 4       id_0002900070228                    P                50512
# ...                  ...                  ...                  ...
# 145639  id_9998599479887                    C                32034
# 145640  id_9998599979836                    P                30078
# 145641  id_9998599979867                    P                49309
# 145642  id_9999599479967                    P                20050
# 145643  id_9999599779976                    P                14061
#
#         ESTADO_PREF_01 PTJE_PREF_01  POND_ACAD_PREF_01  COD_CARRERA_PREF_02  \
# 0                   36            0                  0                16093
# ...

# %% [markdown]
# ## 2017

# %%
df = pd.read_csv("datos_utilizados/postulacion/2017/ArchivoD_Adm2017.csv", sep=";", low_memory=False)

# %%
df
# Out:
#                   ID_aux SITUACION_POSTULANTE  COD_CARRERA_PREF_01  \
# 0       id_0000900070053                    P              40040.0
# 1       id_0000900270060                    C              19026.0
# 2       id_0000900470063                    P              43013.0
# 3       id_0000900470081                    P              14030.0
# 4       id_0000900670008                    P              22059.0
# ...                  ...                  ...                  ...
# 145991  id_9979599877919                    P              26047.0
# 145992  id_9979599877932                    P              16080.0
# 145993  id_9988599678866                    P              12039.0
# 145994  id_9990599179038                    P              11045.0
# 145995  id_9990599479025                    C              13087.0
#
#         ESTADO_PREF_01  PTJE_PREF01  POND_ACAD_PREF01  COD_CARRERA_PREF_02  \
# 0                 24.0      54900.0               1.0              38003.0
# ...
