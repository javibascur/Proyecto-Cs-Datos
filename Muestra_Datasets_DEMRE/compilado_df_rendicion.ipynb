# %% [markdown]
# ## Rendicion

# %%
import pandas as pd

# %% [markdown]
# ## 2023

# %%
df = pd.read_csv("datos_utilizados/rendicion/2023/ArchivoC_Adm2023.csv", sep=";", low_memory=False)

# %%
df = df.drop(columns=["MATE1_REG_ANTERIOR", "HCSOC_REG_ANTERIOR", "CIEN_REG_ANTERIOR", "MODULO_REG_ANTERIOR", "CLEC_REG_ANTERIOR", "RBD", "COD_ENS", "MODULO_INV_ACTUAL", "CIEN_INV_ACTUAL", "HCSOC_INV_ACTUAL", "MATE_INV_ACTUAL", "CLEC_INV_ACTUAL", "MODULO_REG_ACTUAL", "PORC_SUP_NOTAS", "RAMA_EDUCACIONAL", "SITUACION_EGRESO"])

# %%
df
# Out:
#                   ID_aux  GRUPO_DEPENDENCIA  CODIGO_REGION  CODIGO_COMUNA  \
# 0       id_0000900170003                3.0           13.0        13401.0
# 1       id_0000900470024                3.0           13.0        13107.0
# 2       id_0000900670068                2.0            1.0         1101.0
# 3       id_0001900070103                2.0           14.0        14202.0
# 4       id_0001900070149                3.0           14.0        14101.0
# ...                  ...                ...            ...            ...
# 293860  id_9999599979968                2.0           14.0        14106.0
# 293861   id_999990948930                2.0           13.0        13129.0
# 293862   id_999994942103                3.0            4.0         4301.0
# 293863   id_999997943080                NaN            NaN            NaN
# 293864  id_9999999879976                3.0           13.0        13119.0
#
#        PROMEDIO_NOTAS  PTJE_NEM  PTJE_RANKING  CLEC_REG_ACTUAL  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293865 entries, 0 to 293864
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID_aux             293865 non-null  object
#  1   GRUPO_DEPENDENCIA  291232 non-null  float64
#  2   CODIGO_REGION      292597 non-null  float64
#  3   CODIGO_COMUNA      291232 non-null  float64
#  4   PROMEDIO_NOTAS     293865 non-null  object
#  5   PTJE_NEM           293865 non-null  int64
#  6   PTJE_RANKING       293865 non-null  int64
#  7   CLEC_REG_ACTUAL    272568 non-null  float64
#  8   MATE1_REG_ACTUAL   272568 non-null  float64
#  9   MATE2_REG_ACTUAL   272568 non-null  float64
#  10  HCSOC_REG_ACTUAL   272568 non-null  float64
#  11  CIEN_REG_ACTUAL    272568 non-null  float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 26.9+ MB

# %% [markdown]
# ## 2022

# %%
df = pd.read_csv("datos_utilizados/rendicion/2022/ArchivoC_Adm2022.csv", sep=";", low_memory=False)

# %%
df = df.drop(columns=["PROMEDIO_CM_ANTERIOR", "PERCENTIL_CM_ANTERIOR", "MODULO_ANTERIOR", "CIEN_ANTERIOR", "HCSO_ANTERIOR", "MATE_ANTERIOR", "CLEC_ANTERIOR", "RBD", "RAMA_EDUCACIONAL", "SITUACION_EGRESO", "PORC_SUP_NOTAS", "MODULO_ACTUAL", "PROMEDIO_CM_ACTUAL", "PERCENTIL_CM_ACTUAL"])

# %%
df
# Out:
#                   ID_aux  COD_ENS  GRUPO_DEPENDENCIA  CODIGO_REGION  \
# 0       id_0000900070036    310.0                2.0           14.0
# 1       id_0000900370001    363.0                2.0            5.0
# 2       id_0000900370094    363.0                2.0            5.0
# 3       id_0000900370098    310.0                2.0            5.0
# 4       id_0000900470074    363.0                2.0           13.0
# ...                  ...      ...                ...            ...
# 254186  id_9999599979969    310.0                2.0            9.0
# 254187  id_9999599979970    410.0                3.0            9.0
# 254188  id_9999599979971    610.0                3.0            9.0
# 254189  id_9999599979986    310.0                4.0            9.0
# 254190  id_9999599979998    310.0                2.0           13.0
#
#         CODIGO_COMUNA PROMEDIO_NOTAS  PTJE_NEM  PTJE_RANKING  CLEC_ACTUAL  \
# 0             14202.0           5,75       571           571            0
# ...

# %% [markdown]
# ## 2021

# %%
df = pd.read_csv("datos_utilizados/rendicion/2021/ArchivoC_Adm2021.csv", sep=";", low_memory=False)

# %%
df = df.drop(columns=["MODULO_ANTERIOR", "CIEN_ANTERIOR", "HCSO_ANTERIOR", "MATE_ANTERIOR", "RBD", "RAMA_EDUCACIONAL", "SITUACION_EGRESO", "PORC_SUP_NOTAS", "MODULO_ACTUAL", "PERCENTIL_CM_ACTUAL", "PERCENTIL_LM_ANTERIOR", "PROMEDIO_LM_ANTERIOR", "LENG_ANTERIOR", "PROMEDIO_CM_ACTUAL"])

# %%
df
# Out:
#                   ID_aux  COD_ENS  GRUPO_DEPENDENCIA  CODIGO_REGION  \
# 0       id_0000900070018    610.0                2.0           13.0
# 1       id_0000900470042    310.0                2.0           13.0
# 2       id_0000900670095    563.0                2.0            1.0
# 3       id_0000900870002    410.0                3.0            8.0
# 4       id_0001900170136    310.0                2.0           13.0
# ...                  ...      ...                ...            ...
# 238813  id_9999599979991    310.0                4.0            9.0
# 238814  id_9999599979992    610.0                4.0            9.0
# 238815  id_9999599979995    310.0                4.0            9.0
# 238816  id_9999599979997    310.0                3.0           14.0
# 238817  id_9999599979999    610.0                4.0            9.0
#
#         CODIGO_COMUNA PROMEDIO_NOTAS  PTJE_NEM  PTJE_RANKING  CLEC_ACTUAL  \
# 0             13401.0              6       625           713          693
# ...

# %% [markdown]
# ## 2020

# %%
df = pd.read_csv("datos_utilizados/rendicion/2020/ArchivoC_Adm2020.csv", sep=";", low_memory=False)

# %%
df = df.drop(columns=["LENG_ANTERIOR", "MATE_ANTERIOR", "HCSO_ANTERIOR", "CIEN_ANTERIOR", "MODULO_ANTERIOR", "PROMEDIO_LM_ANTERIOR", "PERCENTIL_LM_ANTERIOR", "PERCENTIL_LM_ACTUAL", "PROMEDIO_LM_ACTUAL", "MODULO_ACTUAL", "PORC_SUP_NOTAS", "SITUACION_EGRESO", "RAMA_EDUCACIONAL", "RBD"])

# %%
df
# Out:
#                   ID_aux  COD_ENS  GRUPO_DEPENDENCIA  CODIGO_REGION  \
# 0        id_.9+85.97e+83    510.0                3.0            9.0
# 1       id_0000900070019    363.0                2.0           14.0
# 2       id_0000900070043    363.0                2.0           14.0
# 3       id_0000900270075    563.0                2.0           15.0
# 4       id_0000900470040    363.0                3.0           13.0
# ...                  ...      ...                ...            ...
# 292086  id_9999599479904    510.0                2.0           13.0
# 292087  id_9999599479967    310.0                2.0           13.0
# 292088  id_9999599479973    363.0                2.0           16.0
# 292089  id_9999599479977    310.0                2.0            5.0
# 292090  id_9999599779976    510.0                2.0            4.0
#
#         CODIGO_COMUNA PROMEDIO_NOTAS  PTJE_NEM  PTJE_RANKING  LENG_ACTUAL  \
# 0              9201.0           4,83       372           372            0
# ...

# %% [markdown]
# ## 2019

# %%
df = pd.read_csv("datos_utilizados/rendicion/2019/ArchivoC_Adm2019.csv", sep=";", low_memory=False)

# %%
df = df.drop(columns=["LENG_ANTERIOR", "MATE_ANTERIOR", "HCSO_ANTERIOR", "CIEN_ANTERIOR", "MODULO_ANTERIOR", "PROMEDIO_LM_ANTERIOR", "PERCENTIL_LM_ANTERIOR", "PERCENTIL_LM_ACTUAL", "PROMEDIO_LM_ACTUAL", "MODULO_ACTUAL", "SITUACION_EGRESO", "RAMA_EDUCACIONAL", "RBD"])

# %%
df
# Out:
#                   ID_aux  COD_ENS  GRUPO_DEPENDENCIA  CODIGO_REGION  \
# 0       id_0000900070019    363.0                2.0           14.0
# 1       id_0000900270084    510.0                3.0           15.0
# 2       id_0000900370016    310.0                2.0            5.0
# 3       id_0000900370067    310.0                2.0            5.0
# 4       id_0000900370092    363.0                3.0            5.0
# ...                  ...      ...                ...            ...
# 278282  id_9996599179618    510.0                3.0            9.0
# 278283  id_9997599679743    610.0                2.0           13.0
# 278284  id_9997599779750    410.0                3.0            2.0
# 278285  id_9997939341287    310.0                3.0           13.0
# 278286  id_9998599379869    310.0                3.0            8.0
#
#         CODIGO_COMUNA PROMEDIO_NOTAS  PTJE_NEM  PTJE_RANKING  LENG_ACTUAL  \
# 0             14101.0           6,33       691           731          572
# ...
