# %% [markdown]
# ## Postulaciones

# %%
import pandas as pd

# %% [markdown]
# ## 2023

# %%
df = pd.read_csv("datos_utilizados/postulacion/2023/ArchivoD_Adm2023.csv", sep=";", low_memory=False)

# %%
conservar =  ["ID_aux","SITUACION_POSTULANTE","PTJE_PREF_01","SITUACION_POSTULANTE_BEA","PTJE_PREF_01_BEA","SITUACION_POSTULANTE_PACE","PTJE_PREF_01_PACE"]
df = df.drop(columns=[col for col in df.columns if col not in conservar])

# %%
df
# Out:
#                   ID_aux SITUACION_POSTULANTE PTJE_PREF_01  \
# 0       id_0001900070103                    P        543,9
# 1       id_0001900170136                    P       794,95
# 2       id_0001900670175                    P        570,1
# 3       id_0001900870116                    P        719,9
# 4       id_0002900370264                    P        522,9
# ...                  ...                  ...          ...
# 186059  id_9999599979931                    P        506,9
# 186060  id_9999599979949                    P        539,3
# 186061  id_9999599979953                    P        684,9
# 186062  id_9999599979968                    P        593,3
# 186063   id_999997943080                    P        533,6
#
#        SITUACION_POSTULANTE_BEA  PTJE_PREF_01_BEA SITUACION_POSTULANTE_PACE  \
# 0                           NaN               NaN                       NaN
# 1                           NaN               NaN                       NaN
# ...

# %%
df.dtypes
# Out:
# ID_aux                        object
# SITUACION_POSTULANTE          object
# PTJE_PREF_01                  object
# SITUACION_POSTULANTE_BEA      object
# PTJE_PREF_01_BEA             float64
# SITUACION_POSTULANTE_PACE     object
# PTJE_PREF_01_PACE            float64
# dtype: object

# %% [markdown]
# ## 2022

# %%
df = pd.read_csv("datos_utilizados/postulacion/2022/ArchivoD_Adm2022.csv", sep=";", low_memory=False)

# %%
conservar =  ["ID_aux","SITUACION_POSTULANTE","PTJE_PREF_01","SITUACION_POSTULANTE_BEA","PTJE_PREF_01_BEA","SITUACION_POSTULANTE_PACE","PTJE_PREF_01_PACE"]
df = df.drop(columns=[col for col in df.columns if col not in conservar])

# %%
df
# Out:
#                   ID_aux SITUACION_POSTULANTE PTJE_PREF_01  \
# 0       id_0000900370098                    P        551,1
# 1       id_0001900170136                    P        710,4
# 2       id_0001900170151                    P            0
# 3       id_0001900170189                    C            0
# 4       id_0001900870175                    P        483,1
# ...                  ...                  ...          ...
# 147723  id_9999599979966                    P       571,25
# 147724  id_9999599979967                    P       651,45
# 147725  id_9999599979968                    P       610,95
# 147726  id_9999599979969                    P       559,05
# 147727  id_9999599979971                    P       582,05
#
#        SITUACION_POSTULANTE_BEA  PTJE_PREF_01_BEA SITUACION_POSTULANTE_PACE  \
# 0                           NaN               NaN                       NaN
# 1                           NaN               NaN                       NaN
# ...

# %% [markdown]
# ## 2021

# %%
df = pd.read_csv("datos_utilizados/postulacion/2021/ArchivoD_Adm2021.csv", sep=";", low_memory=False)

# %%
conservar =  ["ID_aux","SITUACION_POSTULANTE","PTJE_PREF_01","SITUACION_POSTULANTE_BEA","PTJE_PREF_01_BEA","SITUACION_POSTULANTE_PACE","PTJE_PREF_01_PACE"]
df = df.drop(columns=[col for col in df.columns if col not in conservar])

# %%
df
# Out:
#                   ID_aux SITUACION_POSTULANTE PTJE_PREF_01  \
# 0       id_0000900870002                    C            0
# 1       id_0001900670106                    P        498,4
# 2       id_0002900070273                    P        597,8
# 3       id_0003900970368                    C            0
# 4       id_0004900170477                    P            0
# ...                  ...                  ...          ...
# 140357  id_9999599979980                    C            0
# 140358  id_9999599979989                    P        534,9
# 140359  id_9999599979991                    P        469,2
# 140360  id_9999599979997                    P        630,8
# 140361  id_9999599979999                    C            0
#
#        SITUACION_POSTULANTE_BEA  PTJE_PREF_01_BEA SITUACION_POSTULANTE_PACE  \
# 0                           NaN               NaN                       NaN
# 1                           NaN               NaN                       NaN
# ...

# %% [markdown]
# ## 2020

# %%
df = pd.read_csv("datos_utilizados/postulacion/2020/ArchivoD_Adm2020.csv", sep=";", low_memory=False)

# %%
conservar =  ["ID_aux","SITUACION_POSTULANTE","PTJE_PREF_01","SITUACION_POSTULANTE_BEA","PTJE_PREF_01_BEA","SITUACION_POSTULANTE_PACE","PTJE_PREF_01_PACE"]
df = df.drop(columns=[col for col in df.columns if col not in conservar])

# %%
df
# Out:
#                   ID_aux SITUACION_POSTULANTE PTJE_PREF_01  \
# 0       id_0000900570066                    C            0
# 1       id_0000900570071                    P        639,7
# 2       id_0000900970028                    P        681,1
# 3       id_0000900970096                    P        509,4
# 4       id_0002900070228                    P        629,2
# ...                  ...                  ...          ...
# 145639  id_9998599479887                    C            0
# 145640  id_9998599979836                    P        620,7
# 145641  id_9998599979867                    P       524,45
# 145642  id_9999599479967                    P        564,6
# 145643  id_9999599779976                    P        540,1
#
#        SITUACION_POSTULANTE_BEA  PTJE_PREF_01_BEA SITUACION_POSTULANTE_PACE  \
# 0                           NaN               NaN                       NaN
# 1                           NaN               NaN                       NaN
# ...

# %% [markdown]
# ## 2019

# %%
df = pd.read_csv("datos_utilizados/postulacion/2019/ArchivoD_Adm2019.csv", sep=";", low_memory=False)

# %%
conservar =  ["ID_aux","SITUACION_POSTULANTE","PTJE_PREF_01","SITUACION_POSTULANTE_BEA","PTJE_PREF_01_BEA","SITUACION_POSTULANTE_PACE","PTJE_PREF_01_PACE"]
df = df.drop(columns=[col for col in df.columns if col not in conservar])

# %%
df
# Out:
#                   ID_aux SITUACION_POSTULANTE PTJE_PREF_01  \
# 0       id_0000900370016                    P       588,55
# 1       id_0000900470020                    P        586,5
# 2       id_0000900970026                    P        638,3
# 3       id_0001900070135                    C            0
# 4       id_0001900170123                    C            0
# ...                  ...                  ...          ...
# 153349  id_9977599877703                    P        622,8
# 153350  id_9979599877997                    P        599,2
# 153351  id_9985599478544                    P        504,8
# 153352  id_9987599278786                    P        545,3
# 153353  id_9997599779750                    C            0
#
#        SITUACION_POSTULANTE_BEA  PTJE_PREF_01_BEA SITUACION_POSTULANTE_PACE  \
# 0                           NaN               NaN                       NaN
# 1                           NaN               NaN                       NaN
# ...
